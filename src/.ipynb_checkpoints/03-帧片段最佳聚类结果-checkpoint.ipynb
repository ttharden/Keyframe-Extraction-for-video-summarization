# %%
import sys
sys.path.append('/media/gpt4-pdf-chatbot-langchain/Keyframe-Extraction-for-video-summarization/src')

from extraction.Keyframe_extraction import scen_keyframe_extraction

# %%
scenes_path='/home/dmeck/Downloads/兔兔没有牙.mp4.scenes.txt'
features_path='/home/dmeck/Downloads/兔兔没有牙-features/features.pkl'
video_path='/home/dmeck/Downloads/兔兔没有牙.mp4'
save_path = '/home/dmeck/Downloads/'
folder_path='兔兔没有牙-features-result'

scen_keyframe_extraction(scenes_path=scenes_path,
                        features_path=features_path,
                        video_path=video_path,
                        save_path=save_path,
                        folder_path=folder_path)
# Out:
# 0 119
#
# ['0', '119']
# 120 307
#
# ['120', '307']
# 308 454
#
# ['308', '454']
# 455 877
#
# ['455', '877']
# 878 1281
#
# ['878', '1281']
# 1282 1388
#
# ['1282', '1388']
# 1389 1598
#
# ['1389', '1598']
# (1599, 768)
#   0%|                                                                                                                            | 0/7 [00:00<?, ?it/s]
# 0 119
# (119, 768)
# 10
# In the process of initialising the center
#   0%|                                                                                                                          | 0/119 [00:00<?, ?it/s]
#
#  13%|██████████████                                                                                                  | 15/119 [00:00<00:00, 149.17it/s]
#
#  26%|█████████████████████████████▏                                                                                  | 31/119 [00:00<00:00, 150.59it/s]
#
#  39%|████████████████████████████████████████████▏                                                                   | 47/119 [00:00<00:00, 153.17it/s]
#
#  53%|███████████████████████████████████████████████████████████▎                                                    | 63/119 [00:00<00:00, 154.10it/s]
#
#  66%|██████████████████████████████████████████████████████████████████████████▎                                     | 79/119 [00:00<00:00, 154.84it/s]
#
#  80%|█████████████████████████████████████████████████████████████████████████████████████████▍                      | 95/119 [00:00<00:00, 155.36it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 153.59it/s]
#
#
#   0%|                                                                                                                          | 0/119 [00:00<?, ?it/s]
#
#   8%|█████████▍                                                                                                       | 10/119 [00:00<00:01, 93.28it/s]
#
#  17%|██████████████████▉                                                                                              | 20/119 [00:00<00:01, 91.92it/s]
#
#  25%|████████████████████████████▍                                                                                    | 30/119 [00:00<00:00, 92.31it/s]
#
#  34%|█████████████████████████████████████▉                                                                           | 40/119 [00:00<00:00, 92.60it/s]
#
#  43%|████████████████████████████████████████████████▍                                                                | 51/119 [00:00<00:00, 96.11it/s]
#
#  51%|█████████████████████████████████████████████████████████▉                                                       | 61/119 [00:00<00:00, 95.00it/s]
#
#  60%|███████████████████████████████████████████████████████████████████▍                                             | 71/119 [00:00<00:00, 93.88it/s]
#
#  68%|████████████████████████████████████████████████████████████████████████████▉                                    | 81/119 [00:00<00:00, 93.59it/s]
#
#  76%|██████████████████████████████████████████████████████████████████████████████████████▍                          | 91/119 [00:00<00:00, 93.63it/s]
#
#  85%|███████████████████████████████████████████████████████████████████████████████████████████████                 | 101/119 [00:01<00:00, 93.75it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00
#  86%|████████████████████████████████████████████████████████████████████████████████████████████████                | 102/119 [00:01<00:00, 53.11it/s]
#
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████▋          | 108/119 [00:02<00:00, 53.09it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:02<00:00, 53.02it/s]
#
#
#   0%|                                                                                                                          | 0/119 [00:00<?, ?it/s]
#
#   4%|████▊                                                                                                             | 5/119 [00:00<00:02, 44.32it/s]
#
#   8%|█████████▍                                                                                                       | 10/119 [00:00<00:02, 44.11it/s]
#
#  13%|██████████████▏                                                                                                  | 15/119 [00:00<00:02, 44.03it/s]
#
#  17%|██████████████████▉                                                                                              | 20/119 [00:00<00:02, 44.02it/s]
#
#  21%|███████████████████████▋                                                                                         | 25/119 [00:00<00:02, 44.08it/s]
#
#  25%|████████████████████████████▍                                                                                    | 30/119 [00:00<00:02, 44.16it/s]
#
#  29%|█████████████████████████████████▏                                                                               | 35/119 [00:00<00:01, 44.13it/s]
#
#  34%|█████████████████████████████████████▉                                                                           | 40/119 [00:00<00:01, 43.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 save_path = '/home/dmeck/Downloads/'
#       5 folder_path='兔兔没有牙-features-result'
# ----> 7 scen_keyframe_extraction(scenes_path=scenes_path,
#       8                         features_path=features_path,
#       9                         video_path=video_path,
#      10                         save_path=save_path,
#      11                         folder_path=folder_path)
#
# File /media/gpt4-pdf-chatbot-langchain/Keyframe-Extraction-for-video-summarization/src/extraction/Keyframe_extraction.py:41, in scen_keyframe_extraction(scenes_path, features_path, video_path, save_path, folder_path)
#      39 sub_features = features[start:end]
#      40 print(sub_features.shape)
# ---> 41 best_labels, best_centers, k, index = kmeans_silhouette(sub_features)
#      42 # print(index)
#      43 final_index = [x + start for x in index]
#
# File /media/gpt4-pdf-chatbot-langchain/Keyframe-Extraction-for-video-summarization/src/extraction/Kmeans_improvment.py:18, in kmeans_silhouette(features)
#      15 best_avg_silhouette = -1
#      17 # Results of the selection of the initial center
# ---> 18 clusters, centers = kmeans_init(features)
#      19 best_centers = None  # 初始化best_centers
#      20 center_indices = None  # 初始化center_indices
#
# File /media/gpt4-pdf-chatbot-langchain/Keyframe-Extraction-for-video-summarization/src/extraction/init_center.py:29, in kmeans_init(data)
#      27 cluster_labels = np.zeros(len(data)).astype(int)
#      28 for k in range(len(data)):
# ---> 29     distances = [np.sqrt(np.sum((data[k] - cen) ** 2)) for cen in center]
#      30     nearest_cluster = np.argmin(distances)
#      31     cluster_labels[k] = nearest_cluster
#
# File /media/gpt4-pdf-chatbot-langchain/Keyframe-Extraction-for-video-summarization/src/extraction/init_center.py:29, in <listcomp>(.0)
#      27 cluster_labels = np.zeros(len(data)).astype(int)
#      28 for k in range(len(data)):
# ---> 29     distances = [np.sqrt(np.sum((data[k] - cen) ** 2)) for cen in center]
#      30     nearest_cluster = np.argmin(distances)
#      31     cluster_labels[k] = nearest_cluster
#
# File <__array_function__ internals>:200, in sum(*args, **kwargs)
#
# File /media/gpt4-pdf-chatbot-langchain/pyenv-video/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2324, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2321         return out
#    2322     return res
# -> 2324 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                       initial=initial, where=where)
#
# File /media/gpt4-pdf-chatbot-langchain/pyenv-video/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
